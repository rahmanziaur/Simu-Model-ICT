# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/Simu-Model-ICT/blob/main/1_Chi_Squared_from_otherRepo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.youtube.com/watch?v=YrhlQB3mQFI
#
# - https://www.youtube.com/watch?v=E0eFZzI9Epo

# %% [markdown]
# - We can always opt for **z-tests, t-tests or ANOVA** when we’re dealing with **continuous variables.**
#
# - **categorical features chi-square test** to be quite helpful.
#
# - **A Chi-Square test** is a test of statistical significance for **categorical variables.**

# %% [markdown]
# ### **One Sample Proportion Test**
#
#  - One Categorical Variable

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Chi Square test**
#
#  - Two Categorical Variables

# %% [markdown]
# ![2.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![8.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **T test**
#
#  - One Continuous Variable
#
#  - One **Continuous** Variable and **Categorical** Variable with **two sub classes**.

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# - **two sample T test**

# %% [markdown]
# ![6.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Correlation (or) two sample test**
#
#  - b/n two continous variables

# %% [markdown]
# ![4.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![5.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### **ANOVA Test**
#
#  - One **Continuous** Variable, **One (or) Two Categorical** Variables with **more than two sub classes**.

# %% [markdown]
# ![7.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# --------------

# %%
# Load libraries
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### **Load Data**

# %%
# Load iris data
iris = load_iris()

# Create features and target
X = iris.data
y = iris.target

# %%
# Convert to categorical data by converting data to integers
X = X.astype(int)

# %% [markdown]
# #### **Compare Chi-Squared Statistics**

# %%
# Select two features with highest chi-squared statistics
chi2_selector = SelectKBest(chi2, k=2)
X_kbest = chi2_selector.fit_transform(X, y)

# %% [markdown]
# #### **View Results**

# %%
# Show results
print('Original number of features:', X.shape[1])
print('Reduced number of features:', X_kbest.shape[1])
# Out:
# Original number of features: 4
# Reduced number of features: 2
