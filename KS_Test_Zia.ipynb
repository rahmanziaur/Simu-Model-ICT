# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/Simu-Model-ICT/blob/main/KS_Test_Zia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import statistics

# Load the data
file_name = "Example_K_S.xlsx"
#path = "C:/Users/usuario/Downloads/"
df = pd.read_excel(file_name)
df = df.sort_values(by = "RN") #ascending = True)
df.head(30)
# Out:
#     SL  RN
# 20  20  33
# 2    2  33
# 17  17  47
# 28  28  47
# 10  10  47
# 13  13  49
# 6    6  49
# 24  24  49
# 12  12  51
# 30  30  51
# 5    5  51
# 23  23  51
# 11  11  53
# 4    4  53
# 29  29  53
# 22  22  53
# 19  19  63
# 1    1  63
# 0    0  67
# 18  18  67
# 21  21  69
# 3    3  69
# 8    8  77
# 26  26  77
# 15  15  77
# 14  14  78
# 7    7  78
# 25  25  78
# 16  16  83
# 9    9  83

# %%
# Step 2 - Add a column 𝑓% (frequency) indicating how many times each number appears.

df["Frecuency"] = df['RN'].map(df['RN'].value_counts())
df = df.drop_duplicates()
df.head(30)
# Out:
#     SL  RN  Frecuency
# 20  20  33          2
# 2    2  33          2
# 17  17  47          3
# 28  28  47          3
# 10  10  47          3
# 13  13  49          3
# 6    6  49          3
# 24  24  49          3
# 12  12  51          4
# 30  30  51          4
# 5    5  51          4
# 23  23  51          4
# 11  11  53          4
# 4    4  53          4
# 29  29  53          4
# 22  22  53          4
# 19  19  63          2
# 1    1  63          2
# 0    0  67          2
# 18  18  67          2
# 21  21  69          2
# 3    3  69          2
# 8    8  77          3
# 26  26  77          3
# 15  15  77          3
# 14  14  78          3
# 7    7  78          3
# 25  25  78          3
# 16  16  83          3
# 9    9  83          3

# %%
df_2 = df
df_2["Count"] = np.arange(1, len(df_2) + 1)

df_2["ORCF"] = df_2["Count"] / len(df) #Observed Relative Cumulative Frequency
df_3 = df_2
df_3.head(30)
# Out:
#     SL  RN  Frecuency  Count      ORCF
# 20  20  33          2      1  0.032258
# 2    2  33          2      2  0.064516
# 17  17  47          3      3  0.096774
# 28  28  47          3      4  0.129032
# 10  10  47          3      5  0.161290
# 13  13  49          3      6  0.193548
# 6    6  49          3      7  0.225806
# 24  24  49          3      8  0.258065
# 12  12  51          4      9  0.290323
# 30  30  51          4     10  0.322581
# 5    5  51          4     11  0.354839
# 23  23  51          4     12  0.387097
# 11  11  53          4     13  0.419355
# 4    4  53          4     14  0.451613
# 29  29  53          4     15  0.483871
# 22  22  53          4     16  0.516129
# 19  19  63          2     17  0.548387
# 1    1  63          2     18  0.580645
# 0    0  67          2     19  0.612903
# 18  18  67          2     20  0.645161
# 21  21  69          2     21  0.677419
# 3    3  69          2     22  0.709677
# 8    8  77          3     23  0.741935
# 26  26  77          3     24  0.774194
# 15  15  77          3     25  0.806452
# 14  14  78          3     26  0.838710
# 7    7  78          3     27  0.870968
# 25  25  78          3     28  0.903226
# 16  16  83          3     29  0.935484
# 9    9  83          3     30  0.967742

# %%
# Step 4 - Add expected relative cumulative frequency column

normal = statistics.NormalDist(50, 10)

df_3["ERCF"] = df_3["RN"].apply(lambda x: normal.cdf(x)) #Expected Relative Cumulative Frequency
df_4 = df_3
df_4.head(30)
# Out:
#     SL  RN  Frecuency  Count      ORCF      ERCF
# 20  20  33          2      1  0.032258  0.044565
# 2    2  33          2      2  0.064516  0.044565
# 17  17  47          3      3  0.096774  0.382089
# 28  28  47          3      4  0.129032  0.382089
# 10  10  47          3      5  0.161290  0.382089
# 13  13  49          3      6  0.193548  0.460172
# 6    6  49          3      7  0.225806  0.460172
# 24  24  49          3      8  0.258065  0.460172
# 12  12  51          4      9  0.290323  0.539828
# 30  30  51          4     10  0.322581  0.539828
# 5    5  51          4     11  0.354839  0.539828
# 23  23  51          4     12  0.387097  0.539828
# 11  11  53          4     13  0.419355  0.617911
# 4    4  53          4     14  0.451613  0.617911
# 29  29  53          4     15  0.483871  0.617911
# 22  22  53          4     16  0.516129  0.617911
# 19  19  63          2     17  0.548387  0.903200
# 1    1  63          2     18  0.580645  0.903200
# 0    0  67          2     19  0.612903  0.955435
# 18  18  67          2     20  0.645161  0.955435
# 21  21  69          2     21  0.677419  0.971283
# 3    3  69          2     22  0.709677  0.971283
# 8    8  77          3     23  0.741935  0.996533
# 26  26  77          3     24  0.774194  0.996533
# 15  15  77          3     25  0.806452  0.996533
# 14  14  78          3     26  0.838710  0.997445
# 7    7  78          3     27  0.870968  0.997445
# 25  25  78          3     28  0.903226  0.997445
# 16  16  83          3     29  0.935484  0.999517
# 9    9  83          3     30  0.967742  0.999517

# %%
df_4["Difference"] = abs(df_4["ORCF"]-df_4["ERCF"])
df_5 = df_4
df_5.head(30)
# Out:
#     SL  RN  Frecuency  Count      ORCF      ERCF  Difference
# 20  20  33          2      1  0.032258  0.044565    0.012307
# 2    2  33          2      2  0.064516  0.044565    0.019951
# 17  17  47          3      3  0.096774  0.382089    0.285314
# 28  28  47          3      4  0.129032  0.382089    0.253056
# 10  10  47          3      5  0.161290  0.382089    0.220798
# 13  13  49          3      6  0.193548  0.460172    0.266624
# 6    6  49          3      7  0.225806  0.460172    0.234366
# 24  24  49          3      8  0.258065  0.460172    0.202108
# 12  12  51          4      9  0.290323  0.539828    0.249505
# 30  30  51          4     10  0.322581  0.539828    0.217247
# 5    5  51          4     11  0.354839  0.539828    0.184989
# 23  23  51          4     12  0.387097  0.539828    0.152731
# 11  11  53          4     13  0.419355  0.617911    0.198557
# 4    4  53          4     14  0.451613  0.617911    0.166299
# 29  29  53          4     15  0.483871  0.617911    0.134040
# 22  22  53          4     16  0.516129  0.617911    0.101782
# 19  19  63          2     17  0.548387  0.903200    0.354812
# 1    1  63          2     18  0.580645  0.903200    0.322554
# 0    0  67          2     19  0.612903  0.955435    0.342531
# 18  18  67          2     20  0.645161  0.955435    0.310273
# 21  21  69          2     21  0.677419  0.971283    0.293864
# 3    3  69          2     22  0.709677  0.971283    0.261606
# 8    8  77          3     23  0.741935  0.996533    0.254598
# 26  26  77          3     24  0.774194  0.996533    0.222339
# 15  15  77          3     25  0.806452  0.996533    0.190081
# 14  14  78          3     26  0.838710  0.997445    0.158735
# 7    7  78          3     27  0.870968  0.997445    0.126477
# 25  25  78          3     28  0.903226  0.997445    0.094219
# 16  16  83          3     29  0.935484  0.999517    0.064033
# 9    9  83          3     30  0.967742  0.999517    0.031775

# %%
Dn = max(df_5["Difference"])
print("The value of Dn is: ", Dn)
# Out:
# The value of Dn is:  0.3548124186401962

# %% [markdown]
# KS Table Here:https://miro.medium.com/v2/resize:fit:828/format:webp/1*-hAGUEOyM8r_hhx9f1qIBw.png

# %%
cv = 0.24

if (Dn <= cv):
    print("H_0: Your data fits with a normal distribution N(50,10)")
else:
    print("H_1: Your data DO NOT fits with a normal distribution N(50,10)")
# Out:
# H_1: Your data DO NOT fits with a normal distribution N(50,10)
