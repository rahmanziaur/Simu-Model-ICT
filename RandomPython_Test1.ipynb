# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmanziaur/Simu-Model-ICT/blob/main/RandomPython_Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# input data for dict
keys = ['sl', 'RN']
values = []

# creating an empty dictionary
output = {}

# adding items to the dictionary using a loop
for key, value in zip(keys, values):
	output[key] = value

# print output
print(output)
# Out:
# {'RN': 0.04232145229757045}

# %%
import random, pandas as pd

# input data for dict
cols = ['Serial', 'Random Number']
values = []

#max length of the random number to generate
max = 100

#unique random number generation using loop
for i in range(0, max):
  values.append(random.uniform(0,1))

# creating an empty dictionary
my_dict = []

#updating dictionary with data
for sl in range(0, max):
    data = {cols[0]: sl, cols[1]: values[sl]}
    my_dict.append(data)

#transforming dictionary into dataframe
df = pd.DataFrame.from_dict(my_dict)

#publishing dataframe as a .csv
df.to_csv('my_500_random_number_between_0_1.csv', index=False)

new_df = pd.read_csv('my_500_random_number_between_0_1.csv')

new_df
# Out:
#     Serial  Random Number
# 0        0       0.235887
# 1        1       0.763947
# 2        2       0.802051
# 3        3       0.715931
# 4        4       0.510015
# ..     ...            ...
# 95      95       0.116671
# 96      96       0.831962
# 97      97       0.338865
# 98      98       0.430560
# 99      99       0.113206
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# new_df['Serial'].plot(kind='hist', bins=20, title='Serial')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# new_df['Random Number'].plot(kind='hist', bins=20, title='Random Number')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# new_df.plot(kind='scatter', x='Serial', y='Random Number', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Serial']
#   ys = series['Random Number']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = new_df.sort_values('Serial', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Serial')
# _ = plt.ylabel('Random Number')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Serial']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Serial'}, axis=1)
#               .sort_values('Serial', ascending=True))
#   xs = counted['Serial']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = new_df.sort_values('Serial', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Serial')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# new_df['Serial'].plot(kind='line', figsize=(8, 4), title='Serial')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# new_df['Random Number'].plot(kind='line', figsize=(8, 4), title='Random Number')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
new_df.plot(kind='scatter', x='Serial', y='Random Number', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
